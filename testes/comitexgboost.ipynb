# %%
import pandas as pd
import numpy as np
from textwrap import shorten
from collections import deque
from datetime import datetime, timedelta
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import os
import glob
import re
import joblib

# %%
# ============================================================================
# FUNÇÕES AUXILIARES
# ============================================================================
todos_jogos_copa = {}

def extrair_gols(placar):
    """Extrai gols do placar no formato 'X-Y'."""
    try:
        gols = str(placar).replace('–', '-').split('-')
        return int(gols[0]), int(gols[1])
    except:
        return 0, 0

def calcular_momentum_ia(deque_resultados):
    """Calcula momentum ponderado dos últimos resultados (V/E/D)."""
    if not deque_resultados:
        return 0
    pontos_map = {'V': 3, 'E': 1, 'D': 0}
    vals = [pontos_map.get(res, 0) for res in deque_resultados]
    pesos = range(1, len(vals) + 1)
    return sum(v * p for v, p in zip(vals, pesos)) / sum(pesos)

def calcular_desespero(pos, rd):
    """Calcula nível de desespero baseado na posição e rodada."""
    if rd < 10:
        return 0
    urgencia = 0
    if pos <= 3:
        urgencia = 1.0  # Título
    elif pos <= 8:
        urgencia = 0.7  # Libertadores
    elif pos >= 17:
        urgencia = 1.2  # Rebaixamento
    elif pos >= 14:
        urgencia = 0.5  # Alerta
    return urgencia * (rd / 38)

def get_proxima_copa(time, data_atual):
    """Retorna código da próxima partida de copa (se houver)."""
    if 'todos_jogos_copa' in globals() and time in todos_jogos_copa:
        proximos = [j for j in todos_jogos_copa[time] if j['data'] > data_atual]
        if proximos:
            prox = min(proximos, key=lambda x: x['data'])
            if (prox['data'] - data_atual).days <= 7:
                return f"{prox['competicao'][0]}{prox['fase'][0]}"
    return '-'

def calcular_soberba(tem_copa, pos_time, pos_adv, rodada):
    """Calcula risco de soberba (poupar jogadores)."""
    if tem_copa == 0:
        return 0
    
    gap_tabela = pos_adv - pos_time
    if gap_tabela > 0:
        sinal = (gap_tabela / 20) ** 2
        return sinal * (rodada / 38)
    return 0

# ============================================================================
# FUNÇÃO PRINCIPAL
# ============================================================================

def gerar_features_completas(df_jogos, df_times, df_copas=None, stats_h2h=None):
    """Gera features completas para modelagem de jogos com correção de KeyError."""
    print("\n--- Integrando Sinais: Momentum, Força e Desespero ---")
    
    # Constantes
    COLUNA_MANDANTE = 'Time da Casa'
    COLUNA_VISITANTE = 'Time Visitante'
    
    if stats_h2h is None:
        stats_h2h = {}
    
    df_jogos['Data_Datetime'] = pd.to_datetime(
        df_jogos['Data'], 
        format='%d/%m/%y', 
        dayfirst=True, 
        errors='coerce'
    )
    # Mapeamento região
    
    df_jogos['Rodada'] = pd.to_numeric(df_jogos['Rodada'], errors='coerce')
    df_jogos = df_jogos.dropna(subset=['Data', 'Rodada']).copy()
    df_jogos = df_jogos[df_jogos['Rodada'].between(1, 38)].copy()
    
    # 🛡️ 1. LIMPEZA INICIAL (Evita quebras por data inválida ou jogos vazios)
    df_jogos = df_jogos.dropna(subset=['Data']).copy()
    df_jogos = df_jogos.sort_values(by='Rodada').reset_index(drop=True)
    
    df_jogos['Gols_Mandante'] = df_jogos['Placar'].apply(lambda p: extrair_gols(p)[0])
    df_jogos['Gols_Visitante'] = df_jogos['Placar'].apply(lambda p: extrair_gols(p)[1])
        
        
    # Média de gols da liga
    media_gols_liga = df_jogos['Gols_Mandante'].mean() if not df_jogos.empty else 1.2
    
    mapa_time_regiao = df_times.set_index('time')['região'].to_dict()
    
    # Times únicos
    unique_teams = pd.concat([df_jogos[COLUNA_MANDANTE], df_jogos[COLUNA_VISITANTE]]).unique()
    
    # ============================================================================
    # INICIALIZAÇÃO DE ESTRUTURAS
    # ============================================================================
    
    stats_times = {time: {
        'pontos': 0, 'jogos': 0, 'vitorias': 0, 'sg_casa': 0, 'sg_fora': 0,
        'gols_marcados_casa': 0, 'gols_sofridos_casa': 0, 'jogos_casa': 0,
        'gols_marcados_fora': 0, 'gols_sofridos_fora': 0, 'jogos_fora': 0,
        'ultimos_5_saldos_casa': deque(maxlen=5),
        'ultimos_5_saldos_fora': deque(maxlen=5),
        'ultimos_5_resultados': deque(maxlen=5)
    } for time in unique_teams}
    
    listas_features = {k: [] for k in [
        'Eh_Serie_B', 'Posicao_Mandante', 'Posicao_Visitante', 'Media_GM_Casa', 
        'Media_GS_Casa', 'Media_GM_Fora', 'Media_GS_Fora', 'Saldo_Gols_Casa_Mandante', 
        'Saldo_Gols_Fora_Visitante', 'Saldo_Ultimos_5_Casa_Mandante', 
        'Saldo_Ultimos_5_Fora_Visitante', 'Sequencia_5_Mandante', 'Sequencia_5_Visitante',
        'Momentum_M', 'Momentum_V', 'Proxima_Copa_Mandante', 'Proxima_Copa_Visitante',
        'Forca_Atk_M', 'Forca_Def_V', 'Sinal_Dominio', 'Desespero_Mandante', 
        'Desespero_Visitante', 'Delta_Desespero', 'Soberba_Mandante', 
        'Soberba_Visitante', 'Delta_Soberba','H2H_Vits_M_Casa', 'H2H_Derrotas_M_Casa', 
        'H2H_Vits_V_Fora', 'H2H_Derrotas_V_Fora', 'H2H_Empates_H2H', 'H2H_Taxa_Vits_M','H2H_Aproveitamento_M'
    ]}
    
    # ============================================================================
    # PROCESSAMENTO RODADA A RODADA
    # ============================================================================
    
    for rodada in range(1, 39):
        # Classificação atual
        df_class = pd.DataFrame.from_dict(stats_times, orient='index')
        df_class['sg_total'] = df_class['sg_casa'] + df_class['sg_fora']
        df_class = df_class.sort_values(by=['pontos', 'vitorias', 'sg_total'], ascending=False)
        df_class['posicao'] = range(1, len(df_class) + 1)
        mapa_posicao = df_class['posicao'].to_dict()
        
        jogos_da_rodada = df_jogos[df_jogos['Rodada'] == rodada]
        
        for index, jogo in jogos_da_rodada.iterrows():
            mandante = str(jogo[COLUNA_MANDANTE]).strip()
            visitante = str(jogo[COLUNA_VISITANTE]).strip()
            data_jogo = jogo['Data_Datetime']
            eh_serie_b = jogo.get('Eh_Serie_B', 0)
            
            m, v = jogo['Time da Casa'], jogo['Time Visitante']
            
            # --------------------------------------------------------------------
            # 🚀 CÁLCULO DO SENSOR H2H (Busca o passado antes deste jogo)
            # --------------------------------------------------------------------
            # Criamos a chave única para o confronto direto com mando de campo
            confronto_direto = (mandante, visitante)
            h2h = stats_h2h.get(confronto_direto, {'v_m': 0, 'v_v': 0, 'e': 0})
            
            # Preenchemos as listas com o histórico ACUMULADO até aqui
            # Após registrar, atualizamos o histórico com o resultado do jogo atual
            g_m, g_v = jogo['Gols_Mandante'], jogo['Gols_Visitante']
            if eh_serie_b == 0: 
                listas_features['H2H_Vits_M_Casa'].append(0)    # Quantas vezes M ganhou de V em casa
                listas_features['H2H_Derrotas_M_Casa'].append(0) # Quantas vezes M perdeu de V em casa
                listas_features['H2H_Vits_V_Fora'].append(0)    # Quantas vezes V ganhou de M fora
                listas_features['H2H_Derrotas_V_Fora'].append(0) # Quantas vezes V perdeu de M fora
                listas_features['H2H_Empates_H2H'].append(0)      # Quantas vezes empataram nesse mando
                listas_features['H2H_Taxa_Vits_M'].append(0.5) # 50% se nunca se enfrentaram
            
            else:
                
                listas_features['H2H_Vits_M_Casa'].append(h2h['v_m'])    # Quantas vezes M ganhou de V em casa
                listas_features['H2H_Derrotas_M_Casa'].append(h2h['v_v']) # Quantas vezes M perdeu de V em casa
                listas_features['H2H_Vits_V_Fora'].append(h2h['v_v'])    # Quantas vezes V ganhou de M fora
                listas_features['H2H_Derrotas_V_Fora'].append(h2h['v_m']) # Quantas vezes V perdeu de M fora
                listas_features['H2H_Empates_H2H'].append(h2h['e'])      # Quantas vezes empataram nesse mando
                
                if confronto_direto not in stats_h2h:
                    stats_h2h[confronto_direto] = {'v_m': 0, 'v_v': 0, 'e': 0}
                
                if g_m > g_v:
                    stats_h2h[confronto_direto]['v_m'] += 3
                elif g_v > g_m:
                    stats_h2h[confronto_direto]['v_v'] += 3
                else:
                    stats_h2h[confronto_direto]['e'] += 1
            
                # Dentro do loop de geração de features, após coletar os H2H:
                total_confrontos = h2h['v_m'] + h2h['v_v'] + h2h['e']
                if total_confrontos > 0:
                    listas_features['H2H_Taxa_Vits_M'].append(h2h['v_m'] / total_confrontos)
                else:
                    listas_features['H2H_Taxa_Vits_M'].append(0.5) # 50% se nunca se enfrentaram
            # --------------------------------------------------------------------
            
            # --- 🕒 H2H COM PESO NO TEMPO (Time-Decay) ---
            total_h2h = h2h['v_m'] + h2h['v_v'] + h2h['e']
            if total_h2h > 0:
                # Em vez de apenas contar, vamos dar peso 1.0 para jogos recentes 
                # e ir diminuindo 0.05 a cada ano de distância.
                # (Essa é uma lógica conceitual, para aplicar no loop de anos)
                # Por enquanto, vamos apenas "diluir" a confiança:
                aprov_m = (h2h['v_m'] + (h2h['e'] * 0.5)) / (total_h2h + 2) # O '+2' atua como 'Dúvida'
                listas_features['H2H_Aproveitamento_M'].append(aprov_m)
            else:
                listas_features['H2H_Aproveitamento_M'].append(0.5)
                
            # --------------------------------------------------------------------
            stats_m, stats_v = stats_times[mandante], stats_times[visitante]
            pos_m, pos_v = mapa_posicao.get(mandante, 21), mapa_posicao.get(visitante, 21)
            
            # --- 🚀 Geração de Features (Compactada para economia) ---
            listas_features['Eh_Serie_B'].append(jogo.get('Eh_Serie_B', 0))
            listas_features['Posicao_Mandante'].append(pos_m)
            listas_features['Posicao_Visitante'].append(pos_v)
            
            d_m, d_v = calcular_desespero(pos_m, rodada), calcular_desespero(pos_v, rodada)
            listas_features['Desespero_Mandante'].append(d_m)
            listas_features['Desespero_Visitante'].append(d_v)
            listas_features['Delta_Desespero'].append(d_m - d_v)
            
            mgm_c = stats_m['gols_marcados_casa'] / stats_m['jogos_casa'] if stats_m['jogos_casa'] > 0 else 0
            mgs_f = stats_v['gols_sofridos_fora'] / stats_v['jogos_fora'] if stats_v['jogos_fora'] > 0 else 0
            
            listas_features['Media_GM_Casa'].append(mgm_c)
            listas_features['Media_GS_Casa'].append(stats_m['gols_sofridos_casa'] / stats_m['jogos_casa'] if stats_m['jogos_casa'] > 0 else 0)
            listas_features['Media_GM_Fora'].append(stats_v['gols_marcados_fora'] / stats_v['jogos_fora'] if stats_v['jogos_fora'] > 0 else 0)
            listas_features['Media_GS_Fora'].append(mgs_f)
            listas_features['Saldo_Gols_Casa_Mandante'].append(stats_m['sg_casa'])
            listas_features['Saldo_Gols_Fora_Visitante'].append(stats_v['sg_fora'])
            listas_features['Saldo_Ultimos_5_Casa_Mandante'].append(sum(stats_m['ultimos_5_saldos_casa']))
            listas_features['Saldo_Ultimos_5_Fora_Visitante'].append(sum(stats_v['ultimos_5_saldos_fora']))
            listas_features['Sequencia_5_Mandante'].append(''.join(stats_m['ultimos_5_resultados']) or '-')
            listas_features['Sequencia_5_Visitante'].append(''.join(stats_v['ultimos_5_resultados']) or '-')
            
            listas_features['Forca_Atk_M'].append(mgm_c / media_gols_liga)
            listas_features['Forca_Def_V'].append(mgs_f / media_gols_liga)
            listas_features['Sinal_Dominio'].append((mgm_c / media_gols_liga) * (mgs_f / media_gols_liga))
            listas_features['Momentum_M'].append(calcular_momentum_ia(stats_m['ultimos_5_resultados']))
            listas_features['Momentum_V'].append(calcular_momentum_ia(stats_v['ultimos_5_resultados']))
            
            prox_c_m = get_proxima_copa(mandante, data_jogo)
            prox_c_v = get_proxima_copa(visitante, data_jogo)
            listas_features['Proxima_Copa_Mandante'].append(prox_c_m)
            listas_features['Proxima_Copa_Visitante'].append(prox_c_v)
            
            c_m = 1 if prox_c_m != '-' else 0
            c_v = 1 if prox_c_v != '-' else 0
            sob_m = calcular_soberba(c_m, pos_m, pos_v, rodada)
            sob_v = calcular_soberba(c_v, pos_v, pos_m, rodada)
            listas_features['Soberba_Mandante'].append(sob_m)
            listas_features['Soberba_Visitante'].append(sob_v)
            listas_features['Delta_Soberba'].append(sob_m - sob_v)
            
            # --- ATUALIZAÇÃO PÓS-JOGO (Mantém o estado do time) ---
            g_m, g_v = jogo['Gols_Mandante'], jogo['Gols_Visitante']
            res_m, res_v = ('V', 'D') if g_m > g_v else (('D', 'V') if g_v > g_m else ('E', 'E'))
            
            stats_m['ultimos_5_saldos_casa'].append(g_m - g_v)
            stats_m['ultimos_5_resultados'].append(res_m)
            stats_m['jogos_casa'] += 1; stats_m['gols_marcados_casa'] += g_m; stats_m['gols_sofridos_casa'] += g_v; stats_m['sg_casa'] += (g_m - g_v)
            stats_v['ultimos_5_saldos_fora'].append(g_v - g_m)
            stats_v['ultimos_5_resultados'].append(res_v)
            stats_v['jogos_fora'] += 1; stats_v['gols_marcados_fora'] += g_v; stats_v['gols_sofridos_fora'] += g_m; stats_v['sg_fora'] += (g_v - g_m)
            
            if g_m > g_v: stats_m['pontos'] += 3; stats_m['vitorias'] += 1
            elif g_v > g_m: stats_v['pontos'] += 3; stats_v['vitorias'] += 1
            else: stats_m['pontos'] += 1; stats_v['pontos'] += 1
    
    # 🛡️ 2. FINALIZAÇÃO (Sincronização Segura)
    for nome, lista in listas_features.items():
        if len(lista) == len(df_jogos):
            df_jogos[nome] = lista
        else:
            # Preenche com zeros se houver erro para não quebrar as próximas linhas
            df_jogos[nome] = [0] * len(df_jogos)
            print(f"⚠️ Alerta Crítico: Coluna {nome} desalinhada. Verifique dados brutos.")

    
    # --- FINALIZAÇÃO (Sincronização Segura) ---
    for nome, lista in listas_features.items():
        if len(lista) == len(df_jogos):
            df_jogos[nome] = lista
        else:
            df_jogos[nome] = [0] * len(df_jogos)
            print(f"⚠️ Alerta Crítico: Coluna {nome} desalinhada.")
    
    df_jogos['Diferenca_Posicao'] = df_jogos['Posicao_Mandante'] - df_jogos['Posicao_Visitante']
    df_jogos['Equilibrio_Posicao'] = (abs(df_jogos['Diferenca_Posicao']) <= 3).astype(int)
    df_jogos['Jogo_de_6_Pontos'] = (abs(df_jogos['Diferenca_Posicao']) <= 4).astype(int)
    df_jogos['Delta_Momentum'] = df_jogos['Momentum_M'] - df_jogos['Momentum_V']
    df_jogos['Soma_Forca_Atk_Def'] = df_jogos['Forca_Atk_M'] + df_jogos['Forca_Def_V']
    df_jogos['Produto_Forca_Atk_Def'] = df_jogos['Forca_Atk_M'] * df_jogos['Forca_Def_V']
    df_jogos['Diferenca_Forca_Atk_Def'] = abs(df_jogos['Forca_Atk_M'] - df_jogos['Forca_Def_V'])
    
    # Clássico regional
    df_jogos['É_Clássico'] = (df_jogos[COLUNA_MANDANTE].map(mapa_time_regiao) == 
                               df_jogos[COLUNA_VISITANTE].map(mapa_time_regiao)).astype(int)
    
    print(f"✅ Sucesso! DF Série {'B' if df_jogos['Eh_Serie_B'].iloc[0] == 1 else 'A'} finalizado.")
    return df_jogos

# %%
# --- ETAPA 1: CARREGAMENTO DOS ARQUIVOS (2006-2012) ---
anos = list(range(2006, 2021))  # 2006 até 2012

# Listas para armazenar todos os DataFrames
df_serie_a_list = []
df_serie_b_list = []
df_times_list = []
df_copa_brasil_list = []
df_libertadores_list = []
df_sudamericana_list = []

for ano in anos:
    print(f"\n📅 Carregando dados de {ano}...")
    
    # Caminhos dos arquivos para o ano atual
    caminho_serie_a = f'dados/brasileiraoA/brasileiraoA{ano}.csv'
    caminho_serie_b = f'dados/brasileiraoB/brasileiraoB{ano}.csv'
    caminho_times = f'dados/times/times{ano}.csv'
    caminho_copa_brasil = f'dados/copadobrasil/copadobrasil{ano}.csv'
    caminho_libertadores = f'dados/libertadores/libertadores{ano}.csv'
    caminho_sudamericana = f'dados/sudamericana/sudamericana{ano}.csv'
    
    try:
        # Carrega cada arquivo e adiciona coluna de ano
        df_a = pd.read_csv(caminho_serie_a)
        df_a['Ano'] = ano
        df_serie_a_list.append(df_a)
        
        df_b = pd.read_csv(caminho_serie_b)
        df_b['Ano'] = ano
        df_serie_b_list.append(df_b)
        
        df_t = pd.read_csv(caminho_times)
        df_t['Ano'] = ano
        df_times_list.append(df_t)
        
        df_cb = pd.read_csv(caminho_copa_brasil)
        df_cb['Ano'] = ano
        df_copa_brasil_list.append(df_cb)
        
        df_lib = pd.read_csv(caminho_libertadores)
        df_lib['Ano'] = ano
        df_libertadores_list.append(df_lib)
        
        df_sud = pd.read_csv(caminho_sudamericana)
        df_sud['Ano'] = ano
        df_sudamericana_list.append(df_sud)
        
        print(f"✅ Dados de {ano} carregados com sucesso!")
        
    except FileNotFoundError as e:
        print(f"⚠️ Aviso: Arquivo de {ano} não encontrado: {e.filename}")
        continue
    except Exception as e:
        print(f"⚠️ Aviso: Erro ao carregar dados de {ano}: {e}")
        continue

# Verifica se há dados carregados
if not df_serie_a_list:
    print("❌ Erro: Nenhum dado da Série A foi carregado!")
    exit()

# Concatena todos os DataFrames
try:
    df_serie_a = pd.concat(df_serie_a_list, ignore_index=True)
    df_serie_b = pd.concat(df_serie_b_list, ignore_index=True)
    df_times = pd.concat(df_times_list, ignore_index=True)
    df_copa_brasil = pd.concat(df_copa_brasil_list, ignore_index=True)
    df_libertadores = pd.concat(df_libertadores_list, ignore_index=True)
    df_sudamericana = pd.concat(df_sudamericana_list, ignore_index=True)
    
except Exception as e:
    print(f"❌ Erro ao concatenar DataFrames: {e}")
    exit()

# --- ETAPA 2: PROCESSAMENTO DOS DADOS DE COPA ---
# --- FUNÇÃO PARA PROCESSAR JOGOS DE COPA ---
def processar_jogos_copa(df_copa, competicao):
    """Processa os jogos de copa e retorna um dicionário com informações por time"""
    jogos_por_time = {}
    
    # Verifica os nomes das colunas e ajusta conforme necessário
    coluna_mandante = None
    coluna_visitante = None
    coluna_data = None
    coluna_fase = None
    
    # Mapeia possíveis nomes de colunas
    possiveis_colunas = {
        'mandante': ['Time Mandante', 'Mandante', 'Time da Casa', 'Casa'],
        'visitante': ['Time Visitante', 'Visitante', 'Time de Fora', 'Fora'],
        'data': ['Data', 'Date', 'Dia'],
        'fase': ['Fase', 'Phase', 'Stage', 'Rodada']
    }
    
    for col in df_copa.columns:
        col_lower = col.lower()
        if any(x.lower() in col_lower for x in possiveis_colunas['mandante']):
            coluna_mandante = col
        elif any(x.lower() in col_lower for x in possiveis_colunas['visitante']):
            coluna_visitante = col
        elif any(x.lower() in col_lower for x in possiveis_colunas['data']):
            coluna_data = col
        elif any(x.lower() in col_lower for x in possiveis_colunas['fase']):
            coluna_fase = col
    
    if not all([coluna_mandante, coluna_visitante, coluna_data]):
        print(f"❌ Colunas não encontradas em {competicao}")
        return jogos_por_time
    
    for _, jogo in df_copa.iterrows():
        try:
            # Converte a data para formato datetime (tenta diferentes formatos)
            data_str = str(jogo[coluna_data])
            data_jogo = None
            
            # Tenta diferentes formatos de data
            formatos_data = ['%d/%m/%y', '%d/%m/%Y', '%Y-%m-%d', '%m/%d/%Y']
            for formato in formatos_data:
                try:
                    data_jogo = datetime.strptime(data_str, formato)
                    break
                except ValueError:
                    continue
            
            if data_jogo is None:
                continue
            
            # Adiciona informações para o time mandante
            mandante = str(jogo[coluna_mandante]).strip()
            if mandante and mandante != 'nan':
                if mandante not in jogos_por_time:
                    jogos_por_time[mandante] = []
                
                fase = str(jogo[coluna_fase]).strip() if coluna_fase else 'F'
                jogos_por_time[mandante].append({
                    'data': data_jogo,
                    'competicao': competicao,
                    'fase': fase,
                    'adversario': str(jogo[coluna_visitante]).strip(),
                    'local': 'casa'
                })
            
            # Adiciona informações para o time visitante
            visitante = str(jogo[coluna_visitante]).strip()
            if visitante and visitante != 'nan':
                if visitante not in jogos_por_time:
                    jogos_por_time[visitante] = []
                
                fase = str(jogo[coluna_fase]).strip() if coluna_fase else 'F'
                jogos_por_time[visitante].append({
                    'data': data_jogo,
                    'competicao': competicao,
                    'fase': fase,
                    'adversario': str(jogo[coluna_mandante]).strip(),
                    'local': 'fora'
                })
            
        except (ValueError, KeyError) as e:
            continue
    
    return jogos_por_time

# Processa os jogos de copa
jogos_copa_brasil = processar_jogos_copa(df_copa_brasil, 'Copa do Brasil')
jogos_libertadores = processar_jogos_copa(df_libertadores, 'Libertadores')
jogos_sudamericana = processar_jogos_copa(df_sudamericana, 'Sudamericana')
    
# Combina os dois dicionários
todos_jogos_copa = {}
for time in set(list(jogos_copa_brasil.keys()) + list(jogos_libertadores.keys()) + list(jogos_sudamericana.keys())):
    todos_jogos_copa[time] = (jogos_copa_brasil.get(time, []) + 
                             jogos_libertadores.get(time, []) + 
                             jogos_sudamericana.get(time, []))

# Ordena os jogos por data para cada time
for time in todos_jogos_copa:
    if todos_jogos_copa[time]:  # Verifica se há jogos
        todos_jogos_copa[time].sort(key=lambda x: x['data'])

def normalizar_times(nome):
    nome = str(nome).strip()
    substituicoes = {
        'Athletico-PR': 'Atlético-PR', 
        'Athletico Paranaense': 'Atlético-PR',
        'Ceará SC': 'Ceará', 
        'Sport Recife': 'Sport',
        'Vasco da Gama': 'Vasco', 
        'América Mineiro': 'América-MG',
        'Atlético Mineiro': 'Atlético-MG', 
        'Atlético Goianiense': 'Atlético-GO',
        'Red Bull Bragantino': 'Bragantino',
        'Grêmio Novorizontino': 'Novorizontino'
    }
    return substituicoes.get(nome, nome)

# --- FUNÇÃO AUXILIAR: Ordenação Natural (1, 2, 10 em vez de 1, 10, 2) ---
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split('([0-9]+)', s)]

# --- ETAPA 3: CARREGAMENTO DOS ARQUIVOS DE SIMULAÇÃO (2006-2012) ---
anos_simulacao = list(range(2006, 2021))
lista_dfs_simulacao = []

print("🚀 Iniciando consolidação dos arquivos de simulação...")

for ano in anos_simulacao:
    caminho_pasta = f'simulacao/{ano}/'
    
    # Verifica se a pasta do ano existe
    if not os.path.exists(caminho_pasta):
        print(f"⚠️ Pasta não encontrada: {caminho_pasta}. Pulando...")
        continue
        
    # Busca arquivos rodada*.csv e ordena corretamente
    arquivos_rodadas = sorted(glob.glob(os.path.join(caminho_pasta, 'rodada*.csv')), key=natural_sort_key)
        
    for arquivo in arquivos_rodadas:
        try:
            df_temp = pd.read_csv(arquivo)
            
            # Adiciona o ano e extrai o número da rodada se não existir
            df_temp['Ano'] = ano
            if 'Rodada' not in df_temp.columns:
                # Extrai o número do nome do arquivo (ex: rodada5.csv -> 5)
                num_rodada = int(re.search(r'rodada(\d+)', arquivo).group(1))
                df_temp['Rodada'] = num_rodada
            
            lista_dfs_simulacao.append(df_temp)
        except Exception as e:
            print(f"⚠️ Erro ao ler {arquivo}: {e}")

# Concatenar todos os DataFrames de simulação
if lista_dfs_simulacao:
    df_simulacao_completo = pd.concat(lista_dfs_simulacao, ignore_index=True)
    
    # Ordenação lógica: primeiro por Ano, depois por Rodada e por fim pelo número do Jogo (1 a 14)
    df_simulacao_completo = df_simulacao_completo.sort_values(by=['Ano', 'Rodada', 'Jogo']).reset_index(drop=True)
    
    # Exibe as primeiras linhas para conferência
    display(df_simulacao_completo.head(15))
else:
    print("❌ Erro: Nenhum arquivo de simulação foi carregado!")

# 1. CRIAMOS A MEMÓRIA VAZIA (SÓ UMA VEZ!)
memoria_h2h = {} 
df_lista_treino = []

# 2. PERCORRENDO OS ANOS (REVEZAMENTO DE DADOS)
for ano in range(2006, 2021):
    
    # Carregue seus dados aqui (exemplo de nomes de arquivos)
    df_a = pd.read_csv(f'dados/brasileiraoA/brasileiraoA{ano}.csv')
    df_b = pd.read_csv(f'dados/brasileiraoB/brasileiraoB{ano}.csv')
    df_t = pd.read_csv(f'dados/times/times{ano}.csv')
    
    # Marcando as séries
    df_a['Eh_Serie_B'] = 0
    df_b['Eh_Serie_B'] = 1
    
    # 🧠 O PULO DO GATO: Passamos a 'memoria_h2h' para a função.
    # Ela vai ler o que já tem lá (anos anteriores) e SALVAR o que acontecer agora.
    df_a_enriq = gerar_features_completas(df_a, df_t, stats_h2h=memoria_h2h)
    df_b_enriq = gerar_features_completas(df_b, df_t, stats_h2h=memoria_h2h)
    
    df_lista_treino.append(df_a_enriq)
    df_lista_treino.append(df_b_enriq)

# 3. UNIFICANDO TUDO EM UM SUPER BANCO DE DADOS
df_total_treino = pd.concat(df_lista_treino, ignore_index=True)

# --- PROVA REAL ---
print("\n📊 Verificação de sanidade do H2H:")
print(f"Total de vitórias acumuladas no H2H: {df_total_treino['H2H_Vits_M_Casa'].sum()}")
# Out:
# 📅 Carregando dados de 2006...
# ✅ Dados de 2006 carregados com sucesso!
#
# 📅 Carregando dados de 2007...
# ✅ Dados de 2007 carregados com sucesso!
#
# 📅 Carregando dados de 2008...
# ✅ Dados de 2008 carregados com sucesso!
#
# 📅 Carregando dados de 2009...
# ✅ Dados de 2009 carregados com sucesso!
#
# 📅 Carregando dados de 2010...
# ✅ Dados de 2010 carregados com sucesso!
#
# 📅 Carregando dados de 2011...
# ✅ Dados de 2011 carregados com sucesso!
#
# 📅 Carregando dados de 2012...
# ✅ Dados de 2012 carregados com sucesso!
#
# 📅 Carregando dados de 2013...
# ✅ Dados de 2013 carregados com sucesso!
#
# 📅 Carregando dados de 2014...
# ✅ Dados de 2014 carregados com sucesso!
#
# 📅 Carregando dados de 2015...
# ✅ Dados de 2015 carregados com sucesso!
#
# 📅 Carregando dados de 2016...
# ✅ Dados de 2016 carregados com sucesso!
#
# 📅 Carregando dados de 2017...
# ✅ Dados de 2017 carregados com sucesso!
#
# 📅 Carregando dados de 2018...
# ✅ Dados de 2018 carregados com sucesso!
#
# 📅 Carregando dados de 2019...
# ✅ Dados de 2019 carregados com sucesso!
#
# 📅 Carregando dados de 2020...
# ✅ Dados de 2020 carregados com sucesso!
# 🚀 Iniciando consolidação dos arquivos de simulação...
#     Jogo      Data  Time da Casa Time Visitante Serie Rodada   Ano
# 0      1  14/04/06          Gama      Vila Nova     B      1  2006
# 1      2  14/04/06       Marília    Atlético-MG     B      1  2006
# 2      3  14/04/06          Avaí          Sport     B      1  2006
# 3      4  14/04/06       Guarani            CRB     B      1  2006
# 4      5  15/04/06     Juventude         Paraná     A      1  2006
# 5      6  15/04/06         Vasco  Internacional     A      1  2006
# 6      7  16/04/06     São Paulo       Flamengo     A      1  2006
# 7      8  16/04/06        Grêmio    Corinthians     A      1  2006
# 8      9  16/04/06      Botafogo      Fortaleza     A      1  2006
# 9     10  16/04/06   São Caetano       Cruzeiro     A      1  2006
# 10    11  16/04/06     Palmeiras    Ponte Preta     A      1  2006
# 11    12  16/04/06    Santa Cruz    Figueirense     A      1  2006
# 12    13  16/04/06  Athletico-PR     Fluminense     A      1  2006
# 13    14  16/04/06         Goiás         Santos     A      1  2006
# 14     1  17/04/06         Sport           Gama     B      2  2006
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
#
# 📊 Verificação de sanidade do H2H:
# Total de vitórias acumuladas no H2H: 8772

# %%
def preparar_para_xgboost(df):
    df_ml = df.copy()
    
    # 1. Variável Alvo (Target) - Tratando possíveis nomes diferentes de colunas
    def definir_alvo(row):
        # Tenta Gols_Mandante ou Gols_M (flexibilidade para seus CSVs)
        gm = row.get('Gols_Mandante', row.get('Gols_M', 0))
        gv = row.get('Gols_Visitante', row.get('Gols_V', 0))
        if gm > gv: return 1   # Vitória Casa
        if gv > gm: return 2   # Vitória Fora
        return 0               # Empate
    
    df_ml['Target'] = df_ml.apply(definir_alvo, axis=1)
    
    # 2. Conversões de Sensores Básicos
    def converter_sequencia(seq):
        if seq == '-' or pd.isna(seq): return 0
        mapa_pts = {'V': 3, 'E': 1, 'D': 0}
        return sum(mapa_pts.get(resultado, 0) for resultado in str(seq))

    # Criando sensores de Ponto e Copa
    if 'Sequencia_5_Mandante' in df_ml.columns:
        df_ml['Pts_Ultimos_5_M'] = df_ml['Sequencia_5_Mandante'].apply(converter_sequencia)
        df_ml['Pts_Ultimos_5_V'] = df_ml['Sequencia_5_Visitante'].apply(converter_sequencia)
    
    if 'Proxima_Copa_Mandante' in df_ml.columns:
        df_ml['Tem_Copa_M'] = (df_ml['Proxima_Copa_Mandante'] != '-').astype(int)
        df_ml['Tem_Copa_V'] = (df_ml['Proxima_Copa_Visitante'] != '-').astype(int)

    # 3. LISTA FINAL DE RECURSOS (33 Sensores)
    colunas_finais = [
        'Rodada', 'Posicao_Mandante', 'Posicao_Visitante', 'Diferenca_Posicao',
        'Media_GM_Casa', 'Media_GS_Casa', 'Media_GM_Fora', 'Media_GS_Fora',
        'Saldo_Gols_Casa_Mandante', 'Saldo_Gols_Fora_Visitante',
        'Saldo_Ultimos_5_Casa_Mandante', 'Saldo_Ultimos_5_Fora_Visitante',
        'Pts_Ultimos_5_M', 'Pts_Ultimos_5_V',
        'Tem_Copa_M', 'Tem_Copa_V', 'É_Clássico', 'Jogo_de_6_Pontos',
        'Forca_Atk_M', 'Forca_Def_V', 'Sinal_Dominio', 
        'Momentum_M', 'Momentum_V', 'Delta_Momentum',
        'Soma_Forca_Atk_Def', 'Produto_Forca_Atk_Def', 'Diferenca_Forca_Atk_Def',
        'Desespero_Mandante', 'Desespero_Visitante', 'Delta_Desespero',
        'Soberba_Mandante', 'Soberba_Visitante', 'Delta_Soberba',
        'H2H_Vits_M_Casa', 'H2H_Derrotas_M_Casa', 
        'H2H_Vits_V_Fora', 'H2H_Derrotas_V_Fora', 'H2H_Empates_H2H', 'H2H_Taxa_Vits_M','H2H_Aproveitamento_M',
    ]

    # --- 🛡️ PROTEÇÃO CONTRA KEYERROR ---
    # Se alguma coluna da lista não existir no DF, cria ela com zero
    for col in colunas_finais:
        if col not in df_ml.columns:
            df_ml[col] = 0

    # 4. Limpeza e Matriz Final
    X = df_ml[colunas_finais].fillna(0)
    y = df_ml['Target']

    return X, y

# --- EXECUÇÃO DO FLUXO ---
# 1. Carrega os dados
df_bruto_a = pd.read_csv(caminho_serie_a)
df_bruto_b = pd.read_csv(caminho_serie_b)

# 2. Gera as features (Sinal de 74.8% + Desespero)
df_enriquecido_a = gerar_features_completas(df_bruto_a, df_times)
df_enriquecido_b = gerar_features_completas(df_bruto_b, df_times)

# 3. Une as bases
df_total_enriquecido = pd.concat([df_enriquecido_a, df_enriquecido_b], ignore_index=True)
print(f"✅ Base unificada com {len(df_total_enriquecido)} jogos.")

# 4. Prepara para o Treino
X, y = preparar_para_xgboost(df_total_enriquecido)
# Out:
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
# ✅ Base unificada com 757 jogos.

# %%
# 1. TREINAMENTO DOS ESPECIALISTAS
def treinar_comite_especialistas(X, y, df_original):
    comite = {}
    acuracias = []
    times = df_original['Time da Casa'].unique()
    
    print(f"🏟️ Treinando {len(times)} especialistas (Foco: Estabilidade)...")
    
    for time in times:
        # Filtra jogos do especialista
        indices_time = df_original[(df_original['Time da Casa'] == time) | 
                                   (df_original['Time Visitante'] == time)].index
        
        X_especialista = X.loc[indices_time]
        y_especialista = y.loc[indices_time]
        
        # 🛡️ Proteção contra erro de Folds (CV Dinâmico)
        contagem_min = y_especialista.value_counts().min()
        n_folds = min(5, contagem_min) if len(y_especialista.value_counts()) >= 3 else 0

        # Configuração enviada por você (XGBoost de Elite)
        ia_time = xgb.XGBClassifier(
            max_depth=3, learning_rate=0.008, n_estimators=1800,
            subsample=0.5, min_child_weight=20, max_delta_step=1,
            colsample_bytree=1, colsample_bylevel=1,
            gamma=2.5, reg_alpha=5, reg_lambda=10.0,
            objective='multi:softprob', random_state=42
        )
        
        # Aplica Calibração se houver dados suficientes, senão vai no seco
        if n_folds >= 2:
            modelo_final = CalibratedClassifierCV(ia_time, method='sigmoid', cv=n_folds)
        else:
            modelo_final = ia_time
            
        modelo_final.fit(X_especialista, y_especialista)
        
        # Teste de Acurácia do Especialista
        preds = modelo_final.predict(X_especialista)
        acc = accuracy_score(y_especialista, preds)
        acuracias.append(acc)
        
        comite[time] = modelo_final
        print(f"✅ {time[:20]:<20} | Acc: {acc:.1%}") # Opcional: ver um por um

    print(f"\n📈 Acurácia Média do Comitê: {np.mean(acuracias):.1%}")
    return comite

# 2. PREDIÇÃO POR CONSENSO
def predicao_consenso(mandante, visitante, input_data, comite):
    # Pede a opinião do dono da casa e do visitante
    prob_m = comite[mandante].predict_proba(input_data)[0]
    prob_v = comite[visitante].predict_proba(input_data)[0]
    
    # Tira a média aritmética das probabilidades
    prob_final = (prob_m + prob_v) / 2
    return prob_final

meu_comite = treinar_comite_especialistas(X, y, df_total_enriquecido)
# Out:
# 🏟️ Treinando 40 especialistas (Foco: Estabilidade)...
# ✅ Fortaleza            | Acc: 52.6%
# ✅ Coritiba             | Acc: 42.1%
# ✅ Sport                | Acc: 50.0%
# ✅ Santos               | Acc: 47.4%
# ✅ Flamengo             | Acc: 42.1%
# ✅ Grêmio               | Acc: 44.7%
# ✅ Corinthians          | Acc: 44.7%
# ✅ Botafogo             | Acc: 34.2%
# ✅ Goiás                | Acc: 44.7%
# ✅ Bragantino           | Acc: 44.7%
# ✅ Atlético-GO          | Acc: 36.8%
# ✅ Bahia                | Acc: 50.0%
# ✅ Fluminense           | Acc: 47.4%
# ✅ São Paulo            | Acc: 42.1%
# ✅ Athletico-PR         | Acc: 50.0%
# ✅ Ceará                | Acc: 36.8%
# ✅ Internacional        | Acc: 47.4%
# ✅ Vasco                | Acc: 45.9%
# ✅ Atlético-MG          | Acc: 60.5%
# ✅ Palmeiras            | Acc: 45.9%
# ✅ Cuiabá               | Acc: 55.3%
# ✅ Juventude            | Acc: 54.1%
# ✅ Operário-PR          | Acc: 47.4%
# ✅ EC Vitória           | Acc: 40.5%
# ✅ Avaí                 | Acc: 44.7%
# ✅ Cruzeiro             | Acc: 36.8%
# ✅ Confiança            | Acc: 44.7%
# ✅ Oeste                | Acc: 44.7%
# ✅ Ponte Preta          | Acc: 50.0%
# ✅ CSA                  | Acc: 52.6%
# ✅ Sampaio Corrêa       | Acc: 42.1%
# ✅ Botafogo-SP          | Acc: 44.7%
# ✅ Brasil-RS            | Acc: 42.1%
# ✅ Guarani              | Acc: 47.4%
# ✅ Paraná               | Acc: 48.6%
# ✅ CRB                  | Acc: 62.2%
# ✅ Figueirense          | Acc: 44.7%
# ✅ América-MG           | Acc: 34.2%
# ✅ Náutico              | Acc: 52.6%
# ✅ Chapecoense          | Acc: 42.1%
#
# 📈 Acurácia Média do Comitê: 46.1%

# %%
import glob
import os
import re
import pandas as pd
import numpy as np

def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split('([0-9]+)', s)]

def converter_sequencia(seq):
    if seq == '-' or pd.isna(seq): return 0
    mapa_pts = {'V': 3, 'E': 1, 'D': 0}
    return sum(mapa_pts.get(resultado, 0) for resultado in seq)

def executar_simulacao_ia_smart_order(diretorio, df_gabarito, modelo_ia, threshold):
    arquivos = sorted(glob.glob(os.path.join(diretorio, 'rodada*.csv')), key=natural_sort_key)
    mapa_res = {1: "CASA  ", 0: "EMPATE", 2: "FORA  "}

    for caminho in arquivos:
        df_concurso = pd.read_csv(caminho)
        nome_arquivo = os.path.basename(caminho)
        jogos_analise = []

        # 1. COLETA DE DADOS (Sem ordenar ainda)
        for i, jogo in df_concurso.iterrows():
            m, v = jogo['Time da Casa'], jogo['Time Visitante']
            jr = df_gabarito[(df_gabarito['Time da Casa'] == m) & (df_gabarito['Time Visitante'] == v)]
            if jr.empty: continue
            
            real_num = 1 if jr['Gols_Mandante'].values[0] > jr['Gols_Visitante'].values[0] else (2 if jr['Gols_Visitante'].values[0] > jr['Gols_Mandante'].values[0] else 0)
            stats_m = df_gabarito[(df_gabarito['Time da Casa'] == m) | (df_gabarito['Time Visitante'] == m)].tail(1)
            stats_v = df_gabarito[(df_gabarito['Time da Casa'] == v) | (df_gabarito['Time Visitante'] == v)].tail(1)

            # (O input_ia deve conter todas as 24 features conforme o teu treino anterior)
            input_ia = pd.DataFrame([{
                'Rodada': jogo['Rodada'], 'Posicao_Mandante': stats_m['Posicao_Mandante'].values[0],
                'Posicao_Visitante': stats_v['Posicao_Visitante'].values[0],
                'Diferenca_Posicao': stats_m['Posicao_Mandante'].values[0] - stats_v['Posicao_Visitante'].values[0],
                'Media_GM_Casa': stats_m['Media_GM_Casa'].values[0], 'Media_GS_Casa': stats_m['Media_GS_Casa'].values[0],
                'Media_GM_Fora': stats_v['Media_GM_Fora'].values[0], 'Media_GS_Fora': stats_v['Media_GS_Fora'].values[0],
                'Saldo_Gols_Casa_Mandante': stats_m['Saldo_Gols_Casa_Mandante'].values[0],
                'Saldo_Gols_Fora_Visitante': stats_v['Saldo_Gols_Fora_Visitante'].values[0],
                'Saldo_Ultimos_5_Casa_Mandante': stats_m['Saldo_Ultimos_5_Casa_Mandante'].values[0],
                'Saldo_Ultimos_5_Fora_Visitante': stats_v['Saldo_Ultimos_5_Fora_Visitante'].values[0],
                'Pts_Ultimos_5_M': converter_sequencia(stats_m['Sequencia_5_Mandante'].values[0]),
                'Pts_Ultimos_5_V': converter_sequencia(stats_v['Sequencia_5_Visitante'].values[0]),
                'Tem_Copa_M': 1 if stats_m['Proxima_Copa_Mandante'].values[0] != '-' else 0,
                'Tem_Copa_V': 1 if stats_v['Proxima_Copa_Visitante'].values[0] != '-' else 0,
                'É_Clássico': jogo['É_Clássico'] if 'É_Clássico' in jogo else 0,
                'Jogo_de_6_Pontos': 1 if abs(stats_m['Posicao_Mandante'].values[0] - stats_v['Posicao_Visitante'].values[0]) <= 4 else 0,
                'Forca_Atk_M': stats_m['Forca_Atk_M'].values[0], 'Forca_Def_V': stats_v['Forca_Def_V'].values[0],
                'Sinal_Dominio': stats_m['Sinal_Dominio'].values[0], 'Momentum_M': stats_m['Momentum_M'].values[0],
                'Momentum_V': stats_v['Momentum_V'].values[0], 'Delta_Momentum': stats_m['Momentum_M'].values[0] - stats_v['Momentum_V'].values[0],
                'Soma_Forca_Atk_Def': stats_m['Soma_Forca_Atk_Def'].values[0],
                'Produto_Forca_Atk_Def': stats_m['Produto_Forca_Atk_Def'].values[0],
                'Diferenca_Forca_Atk_Def': abs(stats_m['Forca_Atk_M'].values[0] - stats_v['Forca_Def_V'].values[0]),
                'Desespero_Mandante': stats_m['Desespero_Mandante'].values[0],
                'Desespero_Visitante': stats_v['Desespero_Visitante'].values[0],
                'Delta_Desespero': stats_m['Delta_Desespero'].values[0],
                'Soberba_Mandante': stats_m['Soberba_Mandante'].values[0],
                'Soberba_Visitante': stats_v['Soberba_Visitante'].values[0],
                'Delta_Soberba': stats_m['Delta_Soberba'].values[0],
                'H2H_Vits_M_Casa': stats_m['H2H_Vits_M_Casa'].values[0],
                'H2H_Derrotas_M_Casa': stats_m['H2H_Derrotas_M_Casa'].values[0],
                'H2H_Vits_V_Fora': stats_v['H2H_Vits_V_Fora'].values[0],
                'H2H_Derrotas_V_Fora': stats_v['H2H_Derrotas_V_Fora'].values[0],
                'H2H_Empates_H2H': stats_m['H2H_Empates_H2H'].values[0],
                'H2H_Taxa_Vits_M': stats_m['H2H_Taxa_Vits_M'].values[0],
                'H2H_Aproveitamento_M': stats_m['H2H_Aproveitamento_M'].values[0]
            }])

            # --- 🎲 CÁLCULO DAS PROBABILIDADES ---
            # ====================================================================
            # 🚀 LÓGICA DE CONSENSO (A OPINIÃO DOS DOIS TIMES)
            # ====================================================================
            # Fallback neutro caso o time não exista no comitê (ex: subiu da Série C)
            # ====================================================================
            # 🚀 LÓGICA DE SELEÇÃO POR MÁXIMA CONFIANÇA
            # ====================================================================
            prob_neutra = np.array([0.34, 0.33, 0.33]) # [Empate, Casa, Fora]

            # 1. Obtemos as predições individuais
            p_m = meu_comite[m].predict_proba(input_ia)[0] if m in meu_comite else prob_neutra
            p_v = meu_comite[v].predict_proba(input_ia)[0] if v in meu_comite else prob_neutra

            # 2. Descobrimos qual especialista está mais convicto (maior valor de probabilidade único)
            confianca_m = np.max(p_m)
            confianca_v = np.max(p_v)

            # 3. O "Voto de Minerva": Escolhemos a distribuição completa do mais confiante
            if confianca_m >= confianca_v:
                probs = p_m
                especialista_vencedor = m
            else:
                probs = p_v
                especialista_vencedor = v

            # Opcional: print para debug durante a avaliação
            print(f"🏟️ {m} vs {v} | Decisão por: {especialista_vencedor} (Conf: {max(confianca_m, confianca_v):.1%})")
            # ====================================================================
            # ====================================================================
            ordem = np.argsort(probs)[::-1] # Índices do maior para o menor
            
            p_casa = probs[1]
            p_empate = probs[0]
            p_fora = probs[2]

            # ====================================================================
            # 🛡️ FILTRO RESTAURADO: REGRA DO EMPATE (25%)
            # ====================================================================
            # Se a chance de empate for >= 25% OU a diferença Casa/Fora for < threshold
            if abs(p_casa - p_fora) < p_empate:
                p_primario = 0  # Prioridade 1: Empate
            else:
                p_primario = np.argmax(probs) # Caso contrário, vai na maior prob
            
            # Define o palpite secundário (o melhor entre os que sobraram)
            p_secundario = ordem[1] if ordem[0] == p_primario else ordem[0]
            # ====================================================================

            jogos_analise.append({
                'id_original': i, 
                'confronto': f"{m[:12]} x {v[:12]}", 'real': real_num, 
                'p1': p_primario, 'p2': p_secundario,
                'gap': abs(p_casa - p_fora), # Gap entre times para decidir Duplos/Triplos
                'probs': probs,
                'p_casa': p_casa, 'p_empate': p_empate, 'p_fora': p_fora,
                'tipo': 'S' 
            })

        # 2. ALOCAÇÃO INTELIGENTE DE RECURSOS
        # Ordenamos temporariamente para decidir onde gastar
        jogos_analise.sort(key=lambda x: x['gap'])
        
        for idx, j in enumerate(jogos_analise):
            if idx == 0: j['tipo'] = 'T' # O mais incerto de todos leva o TRIPLO
            elif idx < 3: j['tipo'] = 'D' # Os próximos 6 levam DUPLO

        # 3. VOLTA À ORDEM ORIGINAL E IMPRIME
        jogos_analise.sort(key=lambda x: x['id_original'])

        print(f"\n# {nome_arquivo.upper()} - BILHETE FINAL #")
        print(f"{'J':<2} | {'CONFRONTO':<32} | {'TIPO':<4} | {'CASA%':<6} | {'EMP%':<6} | {'FORA%':<6} | {'PALPITE':<18} | {'REAL':<8} | {'STATUS'}")        
        print("-" * 130)

        acertos = 0
        for idx, j in enumerate(jogos_analise):
            p_max = np.max(j['probs'])
            
            # Validação
            acertou = (j['tipo'] == "T") or (j['tipo'] == "D" and (j['p1'] == j['real'] or j['p2'] == j['real'])) or (j['tipo'] == "S" and j['p1'] == j['real'])
            if acertou: acertos += 1
            
            palpite_str = "TRIPLO" if j['tipo'] == "T" else (f"{mapa_res[j['p1']]} / {mapa_res[j['p2']]}" if j['tipo'] == "D" else mapa_res[j['p1']])
            status = "✅" if acertou else "❌"
            print(f"{idx+1:<2} | {j['confronto']:<32} | {j['tipo']:<4} | {j['p_casa']:>6.1%} | {j['p_empate']:>6.1%} | {j['p_fora']:>6.1%} | {palpite_str:<18} |{mapa_res[j['real']]:<8}| {status}")
            #print(f"{idx+1:<2} | {j['confronto']:<28} | {j['tipo']:<4} | {p_max:.1%} | {palpite_str:<18} | {mapa_res[j['real']]:<8} | {status}")

        print(f"\n📊 TOTAL: {acertos}/14")
        print(f"📈 ACURÁCIA: {acertos/14:.1%}")

# %%
# 1. LIGAS NACIONAIS
df_13_a = pd.read_csv('dados/brasileiraoA/brasileiraoA2022.csv')
df_13_b = pd.read_csv('dados/brasileiraoB/brasileiraoB2022.csv')
df_13_a['Eh_Serie_B'] = 0
df_13_b['Eh_Serie_B'] = 1

# 2. METADADOS DOS TIMES (Regiões)
df_times_13 = pd.read_csv('dados/times/times2022.csv')

# 3. COMPETIÇÕES DE MATA-MATA (As Copas)
try:
    df_cb_13 = pd.read_csv('dados/copadobrasil/copadobrasil2022.csv')
    df_lib_13 = pd.read_csv('dados/libertadores/libertadores2022.csv')
    df_sud_13 = pd.read_csv('dados/sudamericana/sudamericana2022.csv')
    
    # Unifica todas as copas em um "Calendário Master" para o motor de features
    df_copas_13 = pd.concat([df_cb_13, df_lib_13, df_sud_13], ignore_index=True)
except FileNotFoundError as e:
    print(f"⚠️ Aviso: Algum arquivo de copa não foi encontrado: {e.filename}")
    # Cria um DF vazio com as colunas necessárias para não quebrar a função
    df_copas_13 = pd.DataFrame(columns=['Data', 'Time da Casa', 'Time Visitante'])

# 4. GERAÇÃO DO GABARITO ENRIQUECIDO
# Nota: Certifique-se de que sua função 'gerar_features_completas' aceite o argumento das copas

df_gabarito_13 = pd.concat([
    gerar_features_completas(df_13_a, df_times_13, df_copas_13,memoria_h2h),
    gerar_features_completas(df_13_b, df_times_13, df_copas_13,memoria_h2h)
], ignore_index=True)

# 5. EXECUÇÃO DA SIMULAÇÃO
executar_simulacao_ia_smart_order(
    diretorio='simulacao/2022', 
    df_gabarito=df_gabarito_13, 
    modelo_ia=meu_comite, 
    threshold=0.13
)
# Out:
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série A finalizado.
#
# --- Integrando Sinais: Momentum, Força e Desespero ---
# ✅ Sucesso! DF Série B finalizado.
# 🏟️ Brusque vs Guarani | Decisão por: Guarani (Conf: 44.5%)
# 🏟️ Bahia vs Cruzeiro | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Fluminense vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Atlético-GO vs Flamengo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Palmeiras vs Ceará | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Ponte Preta vs Grêmio | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Coritiba vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Botafogo vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Atlético-MG vs Internacional | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Fortaleza vs Cuiaba | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Avai vs América-MG | Decisão por: América-MG (Conf: 34.3%)
# 🏟️ São Paulo vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Londrina vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Juventude vs Bragantino | Decisão por: Juventude (Conf: 50.0%)
#
# # RODADA1.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Brusque x Guarani                | S    |  44.5% |  25.5% |  29.9% | EMPATE             |CASA    | ❌
# 2  | Bahia x Cruzeiro                 | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 3  | Fluminense x Santos              | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 4  | Atlético-GO x Flamengo           | D    |  40.6% |  23.4% |  36.0% | EMPATE / CASA      |EMPATE  | ✅
# 5  | Palmeiras x Ceará                | S    |  43.2% |  32.3% |  24.5% | EMPATE             |FORA    | ❌
# 6  | Ponte Preta x Grêmio             | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 7  | Coritiba x Goiás                 | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |CASA    | ✅
# 8  | Botafogo x Corinthians           | S    |  42.7% |  31.7% |  25.6% | EMPATE             |FORA    | ❌
# 9  | Atlético-MG x Internaciona       | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 10 | Fortaleza x Cuiaba               | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
# 11 | Avai x América-MG                | T    |  33.9% |  34.3% |  31.8% | TRIPLO             |CASA    | ✅
# 12 | São Paulo x Athletico-PR         | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 13 | Londrina x Náutico               | S    |  49.5% |  35.8% |  14.7% | EMPATE             |CASA    | ❌
# 14 | Juventude x Bragantino           | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Cruzeiro vs Brusque | Decisão por: Cruzeiro (Conf: 36.4%)
# 🏟️ Vila Nova vs Novorizontino | Decisão por: Vila Nova (Conf: 34.0%)
# 🏟️ Náutico vs Bahia | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Goiás vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ América-MG vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Corinthians vs Avai | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Cuiaba vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Operário-PR vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Santos vs Coritiba | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Flamengo vs São Paulo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Athletico-PR vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Internacional vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Bragantino vs Atlético-GO | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Ceará vs Botafogo | Decisão por: Ceará (Conf: 36.1%)
#
# # RODADA2.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Cruzeiro x Brusque               | S    |  29.8% |  33.9% |  36.4% | EMPATE             |CASA    | ❌
# 2  | Vila Nova x Novorizontin         | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |EMPATE  | ✅
# 3  | Náutico x Bahia                  | S    |  49.5% |  35.8% |  14.7% | EMPATE             |FORA    | ❌
# 4  | Goiás x Palmeiras                | S    |  43.2% |  32.3% |  24.5% | EMPATE             |EMPATE  | ✅
# 5  | América-MG x Juventude           | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 6  | Corinthians x Avai               | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 7  | Cuiaba x Fluminense              | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 8  | Operário-PR x Ponte Preta        | S    |  46.8% |  25.5% |  27.6% | EMPATE             |CASA    | ❌
# 9  | Santos x Coritiba                | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 10 | Flamengo x São Paulo             | D    |  40.6% |  23.4% |  36.0% | EMPATE / CASA      |CASA    | ✅
# 11 | Athletico-PR x Atlético-MG       | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
# 12 | Internaciona x Fortaleza         | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 13 | Bragantino x Atlético-GO         | S    |  42.6% |  35.9% |  21.5% | EMPATE             |CASA    | ❌
# 14 | Ceará x Botafogo                 | D    |  36.1% |  27.7% |  36.1% | EMPATE / FORA      |FORA    | ✅
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
# 🏟️ Londrina vs Novorizontino | Decisão por: Londrina (Conf: 34.0%)
# 🏟️ CSA vs Bahia | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Bragantino vs São Paulo | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Athletico-PR vs Flamengo | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Palmeiras vs Corinthians | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Fluminense vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Atlético-MG vs Coritiba | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Ponte Preta vs CRB | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Criciúma vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Santos vs América-MG | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Juventude vs Cuiaba | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Atlético-GO vs Botafogo | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ Avai vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Fortaleza vs Ceará | Decisão por: Fortaleza (Conf: 49.0%)
#
# # RODADA3.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Londrina x Novorizontin          | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |EMPATE  | ✅
# 2  | CSA x Bahia                      | S    |  49.0% |  27.6% |  23.4% | EMPATE             |EMPATE  | ✅
# 3  | Bragantino x São Paulo           | S    |  42.6% |  35.9% |  21.5% | EMPATE             |EMPATE  | ✅
# 4  | Athletico-PR x Flamengo          | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 5  | Palmeiras x Corinthians          | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 6  | Fluminense x Internaciona        | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 7  | Atlético-MG x Coritiba           | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 8  | Ponte Preta x CRB                | S    |  56.1% |  22.2% |  21.7% | CASA               |CASA    | ✅
# 9  | Criciúma x Sport                 | S    |  46.6% |  19.8% |  33.6% | EMPATE             |EMPATE  | ✅
# 10 | Santos x América-MG              | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 11 | Juventude x Cuiaba               | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 12 | Atlético-GO x Botafogo           | D    |  36.1% |  36.1% |  27.7% | EMPATE / CASA      |EMPATE  | ✅
# 13 | Avai x Goiás                     | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |CASA    | ✅
# 14 | Fortaleza x Ceará                | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 7/14
# 📈 ACURÁCIA: 50.0%
# 🏟️ Flamengo vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Bahia vs Sampaio Corrêa | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Cruzeiro vs Londrina | Decisão por: Cruzeiro (Conf: 36.4%)
# 🏟️ Brusque vs CSA | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Vasco vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Ceará vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ América-MG vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Goiás vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Cuiaba vs Atlético-GO | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ Botafogo vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Corinthians vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Coritiba vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Internacional vs Avai | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ São Paulo vs Santos | Decisão por: Santos (Conf: 44.9%)
#
# # RODADA4.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Flamengo x Palmeiras             | S    |  43.2% |  32.3% |  24.5% | EMPATE             |EMPATE  | ✅
# 2  | Bahia x Sampaio Corr             | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 3  | Cruzeiro x Londrina              | T    |  29.8% |  33.9% |  36.4% | TRIPLO             |CASA    | ✅
# 4  | Brusque x CSA                    | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 5  | Vasco x Ponte Preta              | S    |  46.8% |  25.5% |  27.6% | EMPATE             |CASA    | ❌
# 6  | Ceará x Bragantino               | S    |  42.6% |  35.9% |  21.5% | EMPATE             |FORA    | ❌
# 7  | América-MG x Athletico-PR        | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 8  | Goiás x Atlético-MG              | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 9  | Cuiaba x Atlético-GO             | D    |  36.1% |  36.1% |  27.7% | EMPATE / CASA      |EMPATE  | ✅
# 10 | Botafogo x Juventude             | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 11 | Corinthians x Fortaleza          | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 12 | Coritiba x Fluminense            | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 13 | Internaciona x Avai              | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 14 | São Paulo x Santos               | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
# 🏟️ Chapecoense vs Cruzeiro | Decisão por: Chapecoense (Conf: 40.6%)
# 🏟️ CSA vs Sport | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Sampaio Corrêa vs Operário-PR | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Náutico vs Guarani | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Atlético-MG vs América-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Athletico-PR vs Ceará | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Flamengo vs Botafogo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Palmeiras vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Atlético-GO vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Bragantino vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Santos vs Cuiaba | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Juventude vs Internacional | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Fortaleza vs São Paulo | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Avai vs Coritiba | Decisão por: Coritiba (Conf: 40.5%)
#
# # RODADA5.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Chapecoense x Cruzeiro           | S    |  40.6% |  33.8% |  25.6% | EMPATE             |FORA    | ❌
# 2  | CSA x Sport                      | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 3  | Sampaio Corr x Operário-PR       | S    |  44.5% |  32.1% |  23.4% | EMPATE             |EMPATE  | ✅
# 4  | Náutico x Guarani                | S    |  49.5% |  35.8% |  14.7% | EMPATE             |EMPATE  | ✅
# 5  | Atlético-MG x América-MG         | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
# 6  | Athletico-PR x Ceará             | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 7  | Flamengo x Botafogo              | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |FORA    | ✅
# 8  | Palmeiras x Fluminense           | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 9  | Atlético-GO x Goiás              | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |FORA    | ❌
# 10 | Bragantino x Corinthians         | S    |  42.7% |  31.7% |  25.6% | EMPATE             |FORA    | ❌
# 11 | Santos x Cuiaba                  | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 12 | Juventude x Internaciona         | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 13 | Fortaleza x São Paulo            | S    |  49.0% |  29.6% |  21.5% | EMPATE             |EMPATE  | ✅
# 14 | Avai x Coritiba                  | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |CASA    | ✅
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Bahia vs Londrina | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Brusque vs Chapecoense | Decisão por: Chapecoense (Conf: 40.6%)
# 🏟️ Guarani vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Cruzeiro vs Grêmio | Decisão por: Grêmio (Conf: 42.6%)
# 🏟️ Palmeiras vs Bragantino | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Ceará vs Flamengo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Internacional vs Corinthians | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Atlético-MG vs Atlético-GO | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Fluminense vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ São Paulo vs Cuiaba | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Coritiba vs América-MG | Decisão por: Coritiba (Conf: 40.5%)
# 🏟️ Botafogo vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Avai vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Goiás vs Santos | Decisão por: Santos (Conf: 44.9%)
#
# # RODADA6.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Bahia x Londrina                 | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 2  | Brusque x Chapecoense            | S    |  40.6% |  33.8% |  25.6% | EMPATE             |EMPATE  | ✅
# 3  | Guarani x Ponte Preta            | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 4  | Cruzeiro x Grêmio                | S    |  35.9% |  42.6% |  21.5% | EMPATE             |CASA    | ❌
# 5  | Palmeiras x Bragantino           | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 6  | Ceará x Flamengo                 | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |EMPATE  | ✅
# 7  | Internaciona x Corinthians       | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 8  | Atlético-MG x Atlético-GO        | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 9  | Fluminense x Athletico-PR        | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 10 | São Paulo x Cuiaba               | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 11 | Coritiba x América-MG            | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |CASA    | ✅
# 12 | Botafogo x Fortaleza             | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 13 | Avai x Juventude                 | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 14 | Goiás x Santos                   | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 7/14
# 📈 ACURÁCIA: 50.0%
# 🏟️ Bragantino vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Ponte Preta vs Novorizontino | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Sampaio Corrêa vs Vila Nova | Decisão por: Sampaio Corrêa (Conf: 40.2%)
# 🏟️ Criciúma vs CRB | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Vasco vs Bahia | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Atlético-GO vs Coritiba | Decisão por: Coritiba (Conf: 40.5%)
# 🏟️ Flamengo vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Santos vs Ceará | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Juventude vs Palmeiras | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Cuiaba vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ América-MG vs Botafogo | Decisão por: América-MG (Conf: 34.3%)
# 🏟️ Corinthians vs São Paulo | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Fortaleza vs Fluminense | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Athletico-PR vs Avai | Decisão por: Athletico-PR (Conf: 47.0%)
#
# # RODADA7.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Bragantino x Atlético-MG         | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 2  | Ponte Preta x Novorizontin       | S    |  46.8% |  25.5% |  27.6% | EMPATE             |FORA    | ❌
# 3  | Sampaio Corr x Vila Nova         | T    |  40.2% |  19.6% |  40.2% | TRIPLO             |CASA    | ✅
# 4  | Criciúma x CRB                   | S    |  56.1% |  22.2% |  21.7% | CASA               |CASA    | ✅
# 5  | Vasco x Bahia                    | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 6  | Atlético-GO x Coritiba           | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |CASA    | ✅
# 7  | Flamengo x Goiás                 | S    |  42.5% |  27.7% |  29.8% | EMPATE             |CASA    | ❌
# 8  | Santos x Ceará                   | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 9  | Juventude x Palmeiras            | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 10 | Cuiaba x Internaciona            | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 11 | América-MG x Botafogo            | D    |  33.9% |  34.3% |  31.8% | EMPATE / CASA      |EMPATE  | ✅
# 12 | Corinthians x São Paulo          | S    |  42.7% |  31.7% |  25.6% | EMPATE             |EMPATE  | ✅
# 13 | Fortaleza x Fluminense           | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
# 14 | Athletico-PR x Avai              | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 7/14
# 📈 ACURÁCIA: 50.0%
# 🏟️ Novorizontino vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Brusque vs Tombense | Decisão por: Brusque (Conf: 34.0%)
# 🏟️ Operário-PR vs Ituano | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Cruzeiro vs Sampaio Corrêa | Decisão por: Sampaio Corrêa (Conf: 40.2%)
# 🏟️ Goiás vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ São Paulo vs Ceará | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Fortaleza vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Coritiba vs Botafogo | Decisão por: Coritiba (Conf: 40.5%)
# 🏟️ Santos vs Palmeiras | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Cuiaba vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Corinthians vs América-MG | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Fluminense vs Flamengo | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Atlético-MG vs Avai | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Internacional vs Atlético-GO | Decisão por: Internacional (Conf: 44.6%)
#
# # RODADA8.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Novorizontin x Sport             | S    |  46.6% |  19.8% |  33.6% | EMPATE             |EMPATE  | ✅
# 2  | Brusque x Tombense               | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |CASA    | ✅
# 3  | Operário-PR x Ituano             | S    |  44.5% |  32.1% |  23.4% | EMPATE             |CASA    | ❌
# 4  | Cruzeiro x Sampaio Corr          | D    |  40.2% |  19.6% |  40.2% | EMPATE / FORA      |CASA    | ❌
# 5  | Goiás x Bragantino               | S    |  42.6% |  35.9% |  21.5% | EMPATE             |EMPATE  | ✅
# 6  | São Paulo x Ceará                | S    |  40.5% |  31.8% |  27.7% | EMPATE             |EMPATE  | ✅
# 7  | Fortaleza x Juventude            | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 8  | Coritiba x Botafogo              | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |CASA    | ✅
# 9  | Santos x Palmeiras               | S    |  44.9% |  31.7% |  23.4% | EMPATE             |FORA    | ❌
# 10 | Cuiaba x Athletico-PR            | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 11 | Corinthians x América-MG         | S    |  42.7% |  31.7% |  25.6% | EMPATE             |EMPATE  | ✅
# 12 | Fluminense x Flamengo            | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 13 | Atlético-MG x Avai               | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 14 | Internaciona x Atlético-GO       | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
#
# 📊 TOTAL: 8/14
# 📈 ACURÁCIA: 57.1%
# 🏟️ Londrina vs Operário-PR | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Ituano vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Sampaio Corrêa vs Guarani | Decisão por: Guarani (Conf: 44.5%)
# 🏟️ CSA vs Novorizontino | Decisão por: CSA (Conf: 49.0%)
# 🏟️ América-MG vs Cuiaba | Decisão por: América-MG (Conf: 34.3%)
# 🏟️ Athletico-PR vs Santos | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Ceará vs Coritiba | Decisão por: Coritiba (Conf: 40.5%)
# 🏟️ Avai vs São Paulo | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Atlético-GO vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Juventude vs Fluminense | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Flamengo vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Palmeiras vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Bragantino vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Botafogo vs Goiás | Decisão por: Goiás (Conf: 42.5%)
#
# # RODADA9.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Londrina x Operário-PR           | S    |  44.5% |  32.1% |  23.4% | EMPATE             |CASA    | ❌
# 2  | Ituano x Náutico                 | S    |  49.5% |  35.8% |  14.7% | EMPATE             |EMPATE  | ✅
# 3  | Sampaio Corr x Guarani           | S    |  44.5% |  25.5% |  29.9% | EMPATE             |CASA    | ❌
# 4  | CSA x Novorizontin               | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 5  | América-MG x Cuiaba              | T    |  33.9% |  34.3% |  31.8% | TRIPLO             |CASA    | ✅
# 6  | Athletico-PR x Santos            | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 7  | Ceará x Coritiba                 | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |EMPATE  | ✅
# 8  | Avai x São Paulo                 | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |EMPATE  | ✅
# 9  | Atlético-GO x Corinthians        | S    |  42.7% |  31.7% |  25.6% | EMPATE             |FORA    | ❌
# 10 | Juventude x Fluminense           | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 11 | Flamengo x Fortaleza             | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
# 12 | Palmeiras x Atlético-MG          | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 13 | Bragantino x Internaciona        | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 14 | Botafogo x Goiás                 | S    |  42.5% |  27.7% |  29.8% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Sport vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Brusque vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Bahia vs Criciúma | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Novorizontino vs Sampaio Corrêa | Decisão por: Sampaio Corrêa (Conf: 40.2%)
# 🏟️ Cuiaba vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ América-MG vs Ceará | Decisão por: Ceará (Conf: 36.1%)
# 🏟️ Juventude vs Athletico-PR | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Atlético-GO vs Avai | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ Bragantino vs Flamengo | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Fluminense vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Santos vs Internacional | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Palmeiras vs Botafogo | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Coritiba vs São Paulo | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Fortaleza vs Goiás | Decisão por: Fortaleza (Conf: 49.0%)
#
# # RODADA10.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Sport x Ponte Preta              | S    |  46.8% |  25.5% |  27.6% | EMPATE             |CASA    | ❌
# 2  | Brusque x Náutico                | S    |  49.5% |  35.8% |  14.7% | EMPATE             |FORA    | ❌
# 3  | Bahia x Criciúma                 | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 4  | Novorizontin x Sampaio Corr      | T    |  40.2% |  19.6% |  40.2% | TRIPLO             |EMPATE  | ✅
# 5  | Cuiaba x Corinthians             | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 6  | América-MG x Ceará               | D    |  36.1% |  27.7% |  36.1% | EMPATE / FORA      |FORA    | ✅
# 7  | Juventude x Athletico-PR         | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 8  | Atlético-GO x Avai               | D    |  36.1% |  36.1% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 9  | Bragantino x Flamengo            | S    |  42.6% |  35.9% |  21.5% | EMPATE             |CASA    | ❌
# 10 | Fluminense x Atlético-MG         | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 11 | Santos x Internaciona            | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 12 | Palmeiras x Botafogo             | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 13 | Coritiba x São Paulo             | S    |  40.5% |  31.8% |  27.7% | EMPATE             |EMPATE  | ✅
# 14 | Fortaleza x Goiás                | S    |  49.0% |  29.6% |  21.5% | EMPATE             |EMPATE  | ✅
#
# 📊 TOTAL: 7/14
# 📈 ACURÁCIA: 50.0%
# 🏟️ CSA vs Chapecoense | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Náutico vs Vasco | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Grêmio vs Novorizontino | Decisão por: Grêmio (Conf: 42.6%)
# 🏟️ Cruzeiro vs CRB | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Corinthians vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Atlético-MG vs Santos | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Fluminense vs Atlético-GO | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Cuiaba vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Internacional vs Flamengo | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Goiás vs Ceará | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ São Paulo vs América-MG | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Coritiba vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Fortaleza vs Athletico-PR | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Botafogo vs Avai | Decisão por: Avai (Conf: 34.0%)
#
# # RODADA11.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | CSA x Chapecoense                | S    |  49.0% |  27.6% |  23.4% | EMPATE             |EMPATE  | ✅
# 2  | Náutico x Vasco                  | S    |  49.5% |  35.8% |  14.7% | EMPATE             |FORA    | ❌
# 3  | Grêmio x Novorizontin            | S    |  35.9% |  42.6% |  21.5% | EMPATE             |CASA    | ❌
# 4  | Cruzeiro x CRB                   | S    |  56.1% |  22.2% |  21.7% | CASA               |CASA    | ✅
# 5  | Corinthians x Juventude          | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 6  | Atlético-MG x Santos             | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 7  | Fluminense x Atlético-GO         | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 8  | Cuiaba x Bragantino              | S    |  42.6% |  35.9% |  21.5% | EMPATE             |EMPATE  | ✅
# 9  | Internaciona x Flamengo          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 10 | Goiás x Ceará                    | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |EMPATE  | ✅
# 11 | São Paulo x América-MG           | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 12 | Coritiba x Palmeiras             | S    |  43.2% |  32.3% |  24.5% | EMPATE             |FORA    | ❌
# 13 | Fortaleza x Athletico-PR         | S    |  49.0% |  29.6% |  21.5% | EMPATE             |EMPATE  | ✅
# 14 | Botafogo x Avai                  | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |FORA    | ✅
#
# 📊 TOTAL: 8/14
# 📈 ACURÁCIA: 57.1%
# 🏟️ Sampaio Corrêa vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Operário-PR vs Bahia | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Tombense vs CSA | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Vasco vs Cruzeiro | Decisão por: Vasco (Conf: 43.4%)
# 🏟️ Juventude vs Santos | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Ceará vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Bragantino vs Coritiba | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Goiás vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Flamengo vs Cuiaba | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Athletico-PR vs Corinthians | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ América-MG vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Botafogo vs São Paulo | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Palmeiras vs Atlético-GO | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Avai vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
#
# # RODADA12.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Sampaio Corr x Náutico           | S    |  49.5% |  35.8% |  14.7% | EMPATE             |CASA    | ❌
# 2  | Operário-PR x Bahia              | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 3  | Tombense x CSA                   | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 4  | Vasco x Cruzeiro                 | D    |  43.4% |  28.3% |  28.3% | EMPATE / CASA      |CASA    | ✅
# 5  | Juventude x Santos               | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 6  | Ceará x Atlético-MG              | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 7  | Bragantino x Coritiba            | S    |  42.6% |  35.9% |  21.5% | EMPATE             |CASA    | ❌
# 8  | Goiás x Internaciona             | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 9  | Flamengo x Cuiaba                | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |CASA    | ✅
# 10 | Athletico-PR x Corinthians       | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 11 | América-MG x Fluminense          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 12 | Botafogo x São Paulo             | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 13 | Palmeiras x Atlético-GO          | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 14 | Avai x Fortaleza                 | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
# 🏟️ Cruzeiro vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Criciúma vs Brusque | Decisão por: Criciúma (Conf: 34.0%)
# 🏟️ Cuiaba vs Ceará | Decisão por: Ceará (Conf: 36.1%)
# 🏟️ Santos vs Bragantino | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Novorizontino vs Tombense | Decisão por: Novorizontino (Conf: 34.0%)
# 🏟️ Londrina vs Vasco | Decisão por: Vasco (Conf: 43.4%)
# 🏟️ Atlético-MG vs Flamengo | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Coritiba vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Corinthians vs Goiás | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Internacional vs Botafogo | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Fortaleza vs América-MG | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Atlético-GO vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Fluminense vs Avai | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ São Paulo vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
#
# # RODADA13.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Cruzeiro x Ponte Preta           | S    |  46.8% |  25.5% |  27.6% | EMPATE             |CASA    | ❌
# 2  | Criciúma x Brusque               | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |FORA    | ✅
# 3  | Cuiaba x Ceará                   | D    |  36.1% |  27.7% |  36.1% | EMPATE / FORA      |EMPATE  | ✅
# 4  | Santos x Bragantino              | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 5  | Novorizontin x Tombense          | D    |  33.0% |  34.0% |  33.0% | EMPATE / FORA      |FORA    | ✅
# 6  | Londrina x Vasco                 | S    |  43.4% |  28.3% |  28.3% | EMPATE             |FORA    | ❌
# 7  | Atlético-MG x Flamengo           | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 8  | Coritiba x Athletico-PR          | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 9  | Corinthians x Goiás              | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 10 | Internaciona x Botafogo          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 11 | Fortaleza x América-MG           | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 12 | Atlético-GO x Juventude          | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 13 | Fluminense x Avai                | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 14 | São Paulo x Palmeiras            | S    |  43.2% |  32.3% |  24.5% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Chapecoense vs CRB | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Internacional vs Coritiba | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Vasco vs Operário-PR | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Athletico-PR vs Bragantino | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Flamengo vs América-MG | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Corinthians vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Atlético-MG vs Fortaleza | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Criciúma vs Vila Nova | Decisão por: Criciúma (Conf: 34.0%)
# 🏟️ Avai vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Botafogo vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Goiás vs Cuiaba | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Ceará vs Atlético-GO | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ São Paulo vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Ituano vs Cruzeiro | Decisão por: Cruzeiro (Conf: 36.4%)
#
# # RODADA14.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Chapecoense x CRB                | S    |  56.1% |  22.2% |  21.7% | CASA               |FORA    | ❌
# 2  | Internaciona x Coritiba          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 3  | Vasco x Operário-PR              | S    |  44.5% |  32.1% |  23.4% | EMPATE             |CASA    | ❌
# 4  | Athletico-PR x Bragantino        | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 5  | Flamengo x América-MG            | D    |  40.6% |  23.4% |  36.0% | EMPATE / CASA      |CASA    | ✅
# 6  | Corinthians x Santos             | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 7  | Atlético-MG x Fortaleza          | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 8  | Criciúma x Vila Nova             | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |CASA    | ✅
# 9  | Avai x Palmeiras                 | S    |  43.2% |  32.3% |  24.5% | EMPATE             |EMPATE  | ✅
# 10 | Botafogo x Fluminense            | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 11 | Goiás x Cuiaba                   | S    |  42.5% |  27.7% |  29.8% | EMPATE             |CASA    | ❌
# 12 | Ceará x Atlético-GO              | S    |  36.1% |  36.1% |  27.7% | EMPATE             |EMPATE  | ✅
# 13 | São Paulo x Juventude            | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 14 | Ituano x Cruzeiro                | D    |  29.8% |  33.9% |  36.4% | EMPATE / FORA      |EMPATE  | ✅
#
# 📊 TOTAL: 7/14
# 📈 ACURÁCIA: 50.0%
# 🏟️ Operário-PR vs Chapecoense | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Grêmio vs Londrina | Decisão por: Grêmio (Conf: 42.6%)
# 🏟️ Vila Nova vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Brusque vs Bahia | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Juventude vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Fluminense vs Corinthians | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Santos vs Flamengo | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Ceará vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Palmeiras vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Avai vs Cuiaba | Decisão por: Avai (Conf: 34.0%)
# 🏟️ Atlético-GO vs São Paulo | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ América-MG vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Coritiba vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Bragantino vs Botafogo | Decisão por: Bragantino (Conf: 42.6%)
#
# # RODADA15.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Operário-PR x Chapecoense        | S    |  44.5% |  32.1% |  23.4% | EMPATE             |CASA    | ❌
# 2  | Grêmio x Londrina                | S    |  35.9% |  42.6% |  21.5% | EMPATE             |CASA    | ❌
# 3  | Vila Nova x Ponte Preta          | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 4  | Brusque x Bahia                  | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 5  | Juventude x Atlético-MG          | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
# 6  | Fluminense x Corinthians         | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 7  | Santos x Flamengo                | S    |  44.9% |  31.7% |  23.4% | EMPATE             |FORA    | ❌
# 8  | Ceará x Internaciona             | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 9  | Palmeiras x Athletico-PR         | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 10 | Avai x Cuiaba                    | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |FORA    | ✅
# 11 | Atlético-GO x São Paulo          | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |FORA    | ❌
# 12 | América-MG x Goiás               | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |CASA    | ✅
# 13 | Coritiba x Fortaleza             | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 14 | Bragantino x Botafogo            | S    |  42.6% |  35.9% |  21.5% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 4/14
# 📈 ACURÁCIA: 28.6%
# 🏟️ Brusque vs Operário-PR | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Chapecoense vs Sampaio Corrêa | Decisão por: Chapecoense (Conf: 40.6%)
# 🏟️ CRB vs Guarani | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Ponte Preta vs Tombense | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Bragantino vs Avai | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Fluminense vs Ceará | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Goiás vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Coritiba vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Corinthians vs Flamengo | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Santos vs Atlético-GO | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Fortaleza vs Palmeiras | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Atlético-MG vs São Paulo | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Cuiaba vs Botafogo | Decisão por: Cuiaba (Conf: 34.0%)
# 🏟️ Internacional vs América-MG | Decisão por: Internacional (Conf: 44.6%)
#
# # RODADA16.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Brusque x Operário-PR            | S    |  44.5% |  32.1% |  23.4% | EMPATE             |CASA    | ❌
# 2  | Chapecoense x Sampaio Corr       | D    |  40.6% |  33.8% |  25.6% | EMPATE / CASA      |CASA    | ✅
# 3  | CRB x Guarani                    | S    |  56.1% |  22.2% |  21.7% | CASA               |EMPATE  | ❌
# 4  | Ponte Preta x Tombense           | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 5  | Bragantino x Avai                | S    |  42.6% |  35.9% |  21.5% | EMPATE             |CASA    | ❌
# 6  | Fluminense x Ceará               | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 7  | Goiás x Athletico-PR             | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 8  | Coritiba x Juventude             | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 9  | Corinthians x Flamengo           | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 10 | Santos x Atlético-GO             | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 11 | Fortaleza x Palmeiras            | S    |  49.0% |  29.6% |  21.5% | EMPATE             |EMPATE  | ✅
# 12 | Atlético-MG x São Paulo          | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 13 | Cuiaba x Botafogo                | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |CASA    | ✅
# 14 | Internaciona x América-MG        | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
# 🏟️ CSA vs Ponte Preta | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Vila Nova vs Bahia | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Tombense vs Chapecoense | Decisão por: Chapecoense (Conf: 40.6%)
# 🏟️ Guarani vs Cruzeiro | Decisão por: Guarani (Conf: 44.5%)
# 🏟️ Athletico-PR vs Internacional | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Flamengo vs Coritiba | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Avai vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Ceará vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Juventude vs Goiás | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ São Paulo vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Botafogo vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Atlético-GO vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ América-MG vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Palmeiras vs Cuiaba | Decisão por: Palmeiras (Conf: 43.2%)
#
# # RODADA17.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | CSA x Ponte Preta                | S    |  49.0% |  27.6% |  23.4% | EMPATE             |FORA    | ❌
# 2  | Vila Nova x Bahia                | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 3  | Tombense x Chapecoense           | D    |  40.6% |  33.8% |  25.6% | EMPATE / CASA      |CASA    | ✅
# 4  | Guarani x Cruzeiro               | D    |  44.5% |  25.5% |  29.9% | EMPATE / CASA      |CASA    | ✅
# 5  | Athletico-PR x Internaciona      | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 6  | Flamengo x Coritiba              | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |CASA    | ✅
# 7  | Avai x Santos                    | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 8  | Ceará x Corinthians              | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 9  | Juventude x Goiás                | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 10 | São Paulo x Fluminense           | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 11 | Botafogo x Atlético-MG           | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
# 12 | Atlético-GO x Fortaleza          | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
# 13 | América-MG x Bragantino          | S    |  42.6% |  35.9% |  21.5% | EMPATE             |FORA    | ❌
# 14 | Palmeiras x Cuiaba               | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Operário-PR vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Guarani vs Bahia | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ CRB vs Brusque | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Cruzeiro vs Novorizontino | Decisão por: Cruzeiro (Conf: 36.4%)
# 🏟️ Ceará vs Avai | Decisão por: Ceará (Conf: 36.1%)
# 🏟️ Bragantino vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Goiás vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Athletico-PR vs Atlético-GO | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Flamengo vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Internacional vs São Paulo | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Santos vs Botafogo | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Corinthians vs Coritiba | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Cuiaba vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ América-MG vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
#
# # RODADA18.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Operário-PR x Sport              | D    |  46.6% |  19.8% |  33.6% | EMPATE / CASA      |EMPATE  | ✅
# 2  | Guarani x Bahia                  | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 3  | CRB x Brusque                    | S    |  56.1% |  22.2% |  21.7% | CASA               |EMPATE  | ❌
# 4  | Cruzeiro x Novorizontin          | D    |  29.8% |  33.9% |  36.4% | EMPATE / FORA      |CASA    | ❌
# 5  | Ceará x Avai                     | T    |  36.1% |  27.7% |  36.1% | TRIPLO             |CASA    | ✅
# 6  | Bragantino x Fortaleza           | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 7  | Goiás x Fluminense               | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 8  | Athletico-PR x Atlético-GO       | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# ...
# 🏟️ Brusque vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Cruzeiro vs Ituano | Decisão por: Cruzeiro (Conf: 36.4%)
# 🏟️ Bragantino vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ América-MG vs Flamengo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Santos vs Corinthians | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Palmeiras vs Avai | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Fluminense vs Botafogo | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Juventude vs São Paulo | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Coritiba vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Atlético-GO vs Ceará | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ Cuiaba vs Goiás | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Fortaleza vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
#
# # RODADA33.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Novorizontin x Bahia             | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 2  | Vila Nova x Criciúma             | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |CASA    | ✅
# 3  | Brusque x Sport                  | S    |  46.6% |  19.8% |  33.6% | EMPATE             |FORA    | ❌
# 4  | Cruzeiro x Ituano                | D    |  29.8% |  33.9% |  36.4% | EMPATE / FORA      |EMPATE  | ✅
# 5  | Bragantino x Athletico-PR        | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 6  | América-MG x Flamengo            | D    |  40.6% |  23.4% |  36.0% | EMPATE / CASA      |FORA    | ❌
# 7  | Santos x Corinthians             | S    |  44.9% |  31.7% |  23.4% | EMPATE             |FORA    | ❌
# 8  | Palmeiras x Avai                 | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 9  | Fluminense x Botafogo            | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 10 | Juventude x São Paulo            | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 11 | Coritiba x Internaciona          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |EMPATE  | ✅
# 12 | Atlético-GO x Ceará              | S    |  36.1% |  36.1% |  27.7% | EMPATE             |CASA    | ❌
# 13 | Cuiaba x Goiás                   | S    |  42.5% |  27.7% |  29.8% | EMPATE             |FORA    | ❌
# 14 | Fortaleza x Atlético-MG          | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
# 🏟️ Criciúma vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Ponte Preta vs Vila Nova | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Chapecoense vs Operário-PR | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ Sport vs Cruzeiro | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Flamengo vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Athletico-PR vs Palmeiras | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Botafogo vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Corinthians vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Internacional vs Ceará | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Goiás vs América-MG | Decisão por: Goiás (Conf: 42.5%)
# 🏟️ Fortaleza vs Coritiba | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ São Paulo vs Atlético-GO | Decisão por: São Paulo (Conf: 40.5%)
# 🏟️ Atlético-MG vs Juventude | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Cuiaba vs Avai | Decisão por: Cuiaba (Conf: 34.0%)
#
# # RODADA34.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Criciúma x Náutico               | S    |  49.5% |  35.8% |  14.7% | EMPATE             |CASA    | ❌
# 2  | Ponte Preta x Vila Nova          | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 3  | Chapecoense x Operário-PR        | S    |  44.5% |  32.1% |  23.4% | EMPATE             |EMPATE  | ✅
# 4  | Sport x Cruzeiro                 | S    |  46.6% |  19.8% |  33.6% | EMPATE             |CASA    | ❌
# 5  | Flamengo x Santos                | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 6  | Athletico-PR x Palmeiras         | S    |  47.0% |  23.4% |  29.6% | EMPATE             |FORA    | ❌
# 7  | Botafogo x Bragantino            | S    |  42.6% |  35.9% |  21.5% | EMPATE             |CASA    | ❌
# 8  | Corinthians x Fluminense         | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 9  | Internaciona x Ceará             | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 10 | Goiás x América-MG               | D    |  42.5% |  27.7% |  29.8% | EMPATE / CASA      |EMPATE  | ✅
# 11 | Fortaleza x Coritiba             | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 12 | São Paulo x Atlético-GO          | D    |  40.5% |  31.8% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 13 | Atlético-MG x Juventude          | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
# 14 | Cuiaba x Avai                    | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |CASA    | ✅
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Operário-PR vs Brusque | Decisão por: Operário-PR (Conf: 44.5%)
# 🏟️ CSA vs Londrina | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Novorizontino vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Tombense vs Ponte Preta | Decisão por: Ponte Preta (Conf: 46.8%)
# 🏟️ Ceará vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Botafogo vs Cuiaba | Decisão por: Cuiaba (Conf: 34.0%)
# 🏟️ São Paulo vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Athletico-PR vs Goiás | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ América-MG vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Juventude vs Coritiba | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Avai vs Bragantino | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Atlético-GO vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Palmeiras vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Flamengo vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
#
# # RODADA35.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Operário-PR x Brusque            | S    |  44.5% |  32.1% |  23.4% | EMPATE             |EMPATE  | ✅
# 2  | CSA x Londrina                   | S    |  49.0% |  27.6% |  23.4% | EMPATE             |FORA    | ❌
# 3  | Novorizontin x Náutico           | S    |  49.5% |  35.8% |  14.7% | EMPATE             |CASA    | ❌
# 4  | Tombense x Ponte Preta           | S    |  46.8% |  25.5% |  27.6% | EMPATE             |EMPATE  | ✅
# 5  | Ceará x Fluminense               | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |FORA    | ❌
# 6  | Botafogo x Cuiaba                | T    |  33.0% |  34.0% |  33.0% | TRIPLO             |FORA    | ✅
# 7  | São Paulo x Atlético-MG          | S    |  55.3% |  23.3% |  21.4% | CASA               |EMPATE  | ❌
# 8  | Athletico-PR x Goiás             | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 9  | América-MG x Internaciona        | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 10 | Juventude x Coritiba             | S    |  50.0% |  26.0% |  23.9% | CASA               |FORA    | ❌
# 11 | Avai x Bragantino                | S    |  42.6% |  35.9% |  21.5% | EMPATE             |FORA    | ❌
# 12 | Atlético-GO x Santos             | S    |  44.9% |  31.7% |  23.4% | EMPATE             |FORA    | ❌
# 13 | Palmeiras x Fortaleza            | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 14 | Flamengo x Corinthians           | S    |  42.7% |  31.7% |  25.6% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 4/14
# 📈 ACURÁCIA: 28.6%
# 🏟️ Chapecoense vs Tombense | Decisão por: Chapecoense (Conf: 40.6%)
# 🏟️ CRB vs Operário-PR | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Londrina vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ Náutico vs Grêmio | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ Santos vs Avai | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Fluminense vs São Paulo | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Bragantino vs América-MG | Decisão por: Bragantino (Conf: 42.6%)
# 🏟️ Goiás vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Corinthians vs Ceará | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Internacional vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Fortaleza vs Atlético-GO | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Coritiba vs Flamengo | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Cuiaba vs Palmeiras | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Atlético-MG vs Botafogo | Decisão por: Atlético-MG (Conf: 55.3%)
#
# # RODADA36.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Chapecoense x Tombense           | D    |  40.6% |  33.8% |  25.6% | EMPATE / CASA      |CASA    | ✅
# 2  | CRB x Operário-PR                | S    |  56.1% |  22.2% |  21.7% | CASA               |CASA    | ✅
# 3  | Londrina x Sport                 | D    |  46.6% |  19.8% |  33.6% | EMPATE / CASA      |CASA    | ✅
# 4  | Náutico x Grêmio                 | S    |  49.5% |  35.8% |  14.7% | EMPATE             |FORA    | ❌
# 5  | Santos x Avai                    | S    |  44.9% |  31.7% |  23.4% | EMPATE             |EMPATE  | ✅
# 6  | Fluminense x São Paulo           | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 7  | Bragantino x América-MG          | S    |  42.6% |  35.9% |  21.5% | EMPATE             |FORA    | ❌
# 8  | Goiás x Juventude                | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 9  | Corinthians x Ceará              | S    |  42.7% |  31.7% |  25.6% | EMPATE             |CASA    | ❌
# 10 | Internaciona x Athletico-PR      | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 11 | Fortaleza x Atlético-GO          | S    |  49.0% |  29.6% |  21.5% | EMPATE             |EMPATE  | ✅
# 12 | Coritiba x Flamengo              | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |CASA    | ✅
# 13 | Cuiaba x Palmeiras               | S    |  43.2% |  32.3% |  24.5% | EMPATE             |EMPATE  | ✅
# 14 | Atlético-MG x Botafogo           | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
#
# 📊 TOTAL: 8/14
# 📈 ACURÁCIA: 57.1%
# 🏟️ Brusque vs CRB | Decisão por: CRB (Conf: 56.1%)
# 🏟️ CSA vs Vila Nova | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Bahia vs Guarani | Decisão por: Bahia (Conf: 47.0%)
# 🏟️ Chapecoense vs Náutico | Decisão por: Náutico (Conf: 49.5%)
# 🏟️ São Paulo vs Internacional | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Coritiba vs Corinthians | Decisão por: Corinthians (Conf: 42.7%)
# 🏟️ Fluminense vs Goiás | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Avai vs Ceará | Decisão por: Ceará (Conf: 36.1%)
# 🏟️ Fortaleza vs Bragantino | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Juventude vs Flamengo | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ Palmeiras vs América-MG | Decisão por: Palmeiras (Conf: 43.2%)
# 🏟️ Atlético-GO vs Athletico-PR | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Botafogo vs Santos | Decisão por: Santos (Conf: 44.9%)
# 🏟️ Atlético-MG vs Cuiaba | Decisão por: Atlético-MG (Conf: 55.3%)
#
# # RODADA37.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Brusque x CRB                    | S    |  56.1% |  22.2% |  21.7% | CASA               |EMPATE  | ❌
# 2  | CSA x Vila Nova                  | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 3  | Bahia x Guarani                  | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 4  | Chapecoense x Náutico            | S    |  49.5% |  35.8% |  14.7% | EMPATE             |CASA    | ❌
# 5  | São Paulo x Internaciona         | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |FORA    | ❌
# 6  | Coritiba x Corinthians           | S    |  42.7% |  31.7% |  25.6% | EMPATE             |EMPATE  | ✅
# 7  | Fluminense x Goiás               | D    |  44.6% |  27.7% |  27.7% | EMPATE / CASA      |CASA    | ✅
# 8  | Avai x Ceará                     | T    |  36.1% |  27.7% |  36.1% | TRIPLO             |CASA    | ✅
# 9  | Fortaleza x Bragantino           | S    |  49.0% |  29.6% |  21.5% | EMPATE             |CASA    | ❌
# 10 | Juventude x Flamengo             | S    |  50.0% |  26.0% |  23.9% | CASA               |EMPATE  | ❌
# 11 | Palmeiras x América-MG           | S    |  43.2% |  32.3% |  24.5% | EMPATE             |CASA    | ❌
# 12 | Atlético-GO x Athletico-PR       | S    |  47.0% |  23.4% |  29.6% | EMPATE             |EMPATE  | ✅
# 13 | Botafogo x Santos                | S    |  44.9% |  31.7% |  23.4% | EMPATE             |CASA    | ❌
# 14 | Atlético-MG x Cuiaba             | S    |  55.3% |  23.3% |  21.4% | CASA               |CASA    | ✅
#
# 📊 TOTAL: 6/14
# 📈 ACURÁCIA: 42.9%
# 🏟️ Grêmio vs Brusque | Decisão por: Grêmio (Conf: 42.6%)
# 🏟️ Vila Nova vs Sport | Decisão por: Sport (Conf: 46.6%)
# 🏟️ CRB vs Bahia | Decisão por: CRB (Conf: 56.1%)
# 🏟️ Cruzeiro vs CSA | Decisão por: CSA (Conf: 49.0%)
# 🏟️ Flamengo vs Avai | Decisão por: Flamengo (Conf: 40.6%)
# 🏟️ Athletico-PR vs Botafogo | Decisão por: Athletico-PR (Conf: 47.0%)
# 🏟️ Ceará vs Juventude | Decisão por: Juventude (Conf: 50.0%)
# 🏟️ América-MG vs Atlético-GO | Decisão por: Atlético-GO (Conf: 36.1%)
# 🏟️ Santos vs Fortaleza | Decisão por: Fortaleza (Conf: 49.0%)
# 🏟️ Cuiaba vs Coritiba | Decisão por: Coritiba (Conf: 40.5%)
# 🏟️ Bragantino vs Fluminense | Decisão por: Fluminense (Conf: 44.6%)
# 🏟️ Corinthians vs Atlético-MG | Decisão por: Atlético-MG (Conf: 55.3%)
# 🏟️ Internacional vs Palmeiras | Decisão por: Internacional (Conf: 44.6%)
# 🏟️ Goiás vs São Paulo | Decisão por: Goiás (Conf: 42.5%)
#
# # RODADA38.CSV - BILHETE FINAL #
# J  | CONFRONTO                        | TIPO | CASA%  | EMP%   | FORA%  | PALPITE            | REAL     | STATUS
# ----------------------------------------------------------------------------------------------------------------------------------
# 1  | Grêmio x Brusque                 | S    |  35.9% |  42.6% |  21.5% | EMPATE             |CASA    | ❌
# 2  | Vila Nova x Sport                | S    |  46.6% |  19.8% |  33.6% | EMPATE             |EMPATE  | ✅
# 3  | CRB x Bahia                      | S    |  56.1% |  22.2% |  21.7% | CASA               |FORA    | ❌
# 4  | Cruzeiro x CSA                   | S    |  49.0% |  27.6% |  23.4% | EMPATE             |CASA    | ❌
# 5  | Flamengo x Avai                  | T    |  40.6% |  23.4% |  36.0% | TRIPLO             |FORA    | ✅
# 6  | Athletico-PR x Botafogo          | S    |  47.0% |  23.4% |  29.6% | EMPATE             |CASA    | ❌
# 7  | Ceará x Juventude                | S    |  50.0% |  26.0% |  23.9% | CASA               |CASA    | ✅
# 8  | América-MG x Atlético-GO         | D    |  36.1% |  36.1% |  27.7% | EMPATE / CASA      |EMPATE  | ✅
# 9  | Santos x Fortaleza               | S    |  49.0% |  29.6% |  21.5% | EMPATE             |FORA    | ❌
# 10 | Cuiaba x Coritiba                | D    |  40.5% |  27.7% |  31.8% | EMPATE / CASA      |CASA    | ✅
# 11 | Bragantino x Fluminense          | S    |  44.6% |  27.7% |  27.7% | EMPATE             |FORA    | ❌
# 12 | Corinthians x Atlético-MG        | S    |  55.3% |  23.3% |  21.4% | CASA               |FORA    | ❌
# 13 | Internaciona x Palmeiras         | S    |  44.6% |  27.7% |  27.7% | EMPATE             |CASA    | ❌
# 14 | Goiás x São Paulo                | S    |  42.5% |  27.7% |  29.8% | EMPATE             |FORA    | ❌
#
# 📊 TOTAL: 5/14
# 📈 ACURÁCIA: 35.7%
